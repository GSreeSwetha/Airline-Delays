# %% [markdown]
# # Flight Accidents

# %% [markdown]
# Given:
# We have full_flight_delay.csv dataset for analysis which is related to flight delays due to weather conditions.

# %%
from pandas_profiling import ProfileReport

# %%
pip install pandas_profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Data loading

# %%
app_data = pd.read_csv("C:\\Users\\furni\\OneDrive - Northeastern University\Desktop\\full_data_flightdelay.csv")

# %%
app_data.head()
# Out:
#    MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  SEGMENT_NUMBER  \
# 0      1            7          0    0800-0859               2               1
# 1      1            7          0    0700-0759               7               1
# 2      1            7          0    0600-0659               7               1
# 3      1            7          0    0600-0659               9               1
# 4      1            7          0    0001-0559               7               1
#
#    CONCURRENT_FLIGHTS  NUMBER_OF_SEATS            CARRIER_NAME  \
# 0                  25              143  Southwest Airlines Co.
# 1                  29              191    Delta Air Lines Inc.
# 2                  27              199    Delta Air Lines Inc.
# 3                  27              180    Delta Air Lines Inc.
# 4                  10              182        Spirit Air Lines
#
#    AIRPORT_FLIGHTS_MONTH  ...  PLANE_AGE       DEPARTING_AIRPORT  LATITUDE  \
# ...

# %% [markdown]
# Data Profiling

# %%
profile = ProfileReport(app_data, minimal=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-12-09 23:10:07.523086&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#data row count
print(app_data.shape)
# Out:
# (6489062, 26)

# %%
print(f'No of Rows in Data Set: {len(app_data)}')
# Out:
# No of Rows in Data Set: 6489062

# %%
#distribution of the data
#pd.set_option("max_columns", None)
app_data.describe()
# Out:
#               MONTH   DAY_OF_WEEK     DEP_DEL15  DISTANCE_GROUP  \
# count  6.489062e+06  6.489062e+06  6.489062e+06    6.489062e+06
# mean   6.607062e+00  3.935598e+00  1.891441e-01    3.821102e+00
# std    3.396853e+00  1.995200e+00  3.916231e-01    2.382233e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00    1.000000e+00
# 25%    4.000000e+00  2.000000e+00  0.000000e+00    2.000000e+00
# 50%    7.000000e+00  4.000000e+00  0.000000e+00    3.000000e+00
# 75%    1.000000e+01  6.000000e+00  0.000000e+00    5.000000e+00
# max    1.200000e+01  7.000000e+00  1.000000e+00    1.100000e+01
#
#        SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# count    6.489062e+06        6.489062e+06     6.489062e+06
# mean     3.046890e+00        2.783675e+01     1.337397e+02
# std      1.757864e+00        2.151060e+01     4.645213e+01
# min      1.000000e+00        1.000000e+00     4.400000e+01
# 25%      2.000000e+00        1.100000e+01     9.000000e+01
# ...

# %%
#Datatypes of the columns
app_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6489062 entries, 0 to 6489061
# Data columns (total 26 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   MONTH                          int64
#  1   DAY_OF_WEEK                    int64
#  2   DEP_DEL15                      int64
#  3   DEP_TIME_BLK                   object
#  4   DISTANCE_GROUP                 int64
#  5   SEGMENT_NUMBER                 int64
#  6   CONCURRENT_FLIGHTS             int64
#  7   NUMBER_OF_SEATS                int64
#  8   CARRIER_NAME                   object
#  9   AIRPORT_FLIGHTS_MONTH          int64
#  10  AIRLINE_FLIGHTS_MONTH          int64
#  11  AIRLINE_AIRPORT_FLIGHTS_MONTH  int64
#  12  AVG_MONTHLY_PASS_AIRPORT       int64
#  13  AVG_MONTHLY_PASS_AIRLINE       int64
#  14  FLT_ATTENDANTS_PER_PASS        float64
#  15  GROUND_SERV_PER_PASS           float64
#  16  PLANE_AGE                      int64
# ...

# %% [markdown]
# Finding Null values

# %%
#Sum of null values in each column of Application DF
null_vals = app_data.isnull().sum()

# %%
print(null_vals)
# Out:
# MONTH                            0
# DAY_OF_WEEK                      0
# DEP_DEL15                        0
# DEP_TIME_BLK                     0
# DISTANCE_GROUP                   0
# SEGMENT_NUMBER                   0
# CONCURRENT_FLIGHTS               0
# NUMBER_OF_SEATS                  0
# CARRIER_NAME                     0
# AIRPORT_FLIGHTS_MONTH            0
# AIRLINE_FLIGHTS_MONTH            0
# AIRLINE_AIRPORT_FLIGHTS_MONTH    0
# AVG_MONTHLY_PASS_AIRPORT         0
# AVG_MONTHLY_PASS_AIRLINE         0
# FLT_ATTENDANTS_PER_PASS          0
# GROUND_SERV_PER_PASS             0
# PLANE_AGE                        0
# DEPARTING_AIRPORT                0
# LATITUDE                         0
# LONGITUDE                        0
# PREVIOUS_AIRPORT                 0
# PRCP                             0
# SNOW                             0
# SNWD                             0
# TMAX                             0
# AWND                             0
# dtype: int64

# %%
null_vals_app_data = pd.DataFrame({"columns": null_vals.index, "Number of null values": null_vals.values})

# %%
pd.set_option("display.max_rows",None)

#null_vals_app_data

# %%
print(app_data.nunique())
# Out:
# MONTH                              12
# DAY_OF_WEEK                         7
# DEP_DEL15                           2
# DEP_TIME_BLK                       19
# DISTANCE_GROUP                     11
# SEGMENT_NUMBER                     15
# CONCURRENT_FLIGHTS                107
# NUMBER_OF_SEATS                    82
# CARRIER_NAME                       17
# AIRPORT_FLIGHTS_MONTH             969
# AIRLINE_FLIGHTS_MONTH             204
# AIRLINE_AIRPORT_FLIGHTS_MONTH    2119
# AVG_MONTHLY_PASS_AIRPORT           96
# AVG_MONTHLY_PASS_AIRLINE           17
# FLT_ATTENDANTS_PER_PASS            14
# GROUND_SERV_PER_PASS               17
# PLANE_AGE                          33
# DEPARTING_AIRPORT                  96
# LATITUDE                           96
# LONGITUDE                          96
# PREVIOUS_AIRPORT                  356
# PRCP                              305
# SNOW                               75
# SNWD                               28
# TMAX                              124
# ...

# %% [markdown]
# print(app_data)

# %% [markdown]
# Inference: The dataset doesn't have any null values

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #Finding outliers

# %%
#function to drop outliers
def drop_outliers(df,outliers):
    q1=df.quantile(0.05)
    q3=df.quantile(0.95)
    IQR=q3-q1
    not_outliers=df[~((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    outliers_dropped = outliers.dropna().reset_index()
    return not_outliers

#function to find outliers
def find_outliers(df):
    q1=df.quantile(0.05)
    q3=df.quantile(0.95)
    IQR=q3-q1
    outliers=df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    return outliers

# %%
#find outliers in Segment_number
outliers=find_outliers(app_data['SEGMENT_NUMBER'])

len(outliers)
# Out:
# 326

# %%
#outliers index
print(outliers.index)
# Out:
# Int64Index([ 140608,  338464,  338465,  416019,  437569,  440961,  461314,
#              465871,  483507,  483583,
#             ...
#             6136129, 6456962, 6463390, 6463476, 6471000, 6479514, 6480581,
#             6480744, 6481956, 6489023],
#            dtype='int64', length=326)

# %%
#find outliers in NUMBER_OF_SEATS
outliers=find_outliers(app_data['NUMBER_OF_SEATS'])

len(outliers)
# Out:
# 0

# %% [markdown]
# #Drop outliers

# %%
# drop outliers in data
# data=app_data.drop(outliers.index)
# print(len(data))

# %% [markdown]
# #Univariate and bivariate analysis

# %%
#funtion to make univariate distribution. Input is  column value
def univariateDistribution(x):
    des=app_data[x].describe()
    figure,axis = plt.subplots(nrows=1,ncols=2,dpi=500,sharex=False,sharey=False)
    figure.suptitle(x,fontsize=20)
    axis[0].title.set_text('distribution')
    variable=app_data[x].fillna(app_data[x].mean())
    breaks=np.quantile(variable, q=np.linspace(0,1,11))
    variable=variable[(variable>breaks[0]) & (variable<breaks[10])]
    
    #plot distplot
    sns.distplot(variable,hist=True,kde=True, kde_kws={"shade":True},ax=axis[0])

    #Segmentation lines
    axis[0].axvline(des.loc["25%"],ls='--')
    axis[0].axvline(des.loc["mean"],ls='--')
    axis[0].axvline(des.loc["75%"],ls='--')
    des=round(des,2).apply(lambda x : str(x))
    box='\n'.join(("min:"+des.loc["min"],"25%:"+des.loc["25%"],"mean:"+des.loc["mean"],"75%:"+des.loc["75%"],"max:"+des.loc["max"]))
    axis[0].text(0.95,0.95,box,transform=axis[0].transAxes,fontsize=10,va='top',ha="right") #more there

    ##boxplot
    axis[1].title.set_text('outliers')
    tmp_data=pd.DataFrame(app_data[x])
    tmp_data[x]=np.log(tmp_data[x])
    tmp_data.boxplot(column=x,ax=axis[1])
    plt.show()

# %%
#univariate distribution of segments
univariateDistribution('SEGMENT_NUMBER')
# Out:
# C:\Users\furni\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#univariate distribution of segments
univariateDistribution('NUMBER_OF_SEATS')
# Out:
# C:\Users\furni\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Standardizing data

# %% [markdown]
# Inference : The dataset doesn't have any null values, incorrect data. Most of the fields having 0's are relevant values. We dropped duplicates and analyzed outliers. We decided to not remove the outliers as thevalues are relevant for the dataset

# %% [markdown]
# Exporting Cleansed Data Set

# %%
app_data.to_csv('C:\\Users\\furni\\OneDrive - Northeastern University\\Desktop\\new_flight_cleansed_new.csv')
